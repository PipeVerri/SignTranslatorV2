# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Testeo mediapipe
#
# Voy a usar este notebook para probar mediapipe y mis funciones dedicadas al parsing de video y rendering de landmarks

# %%
import mediapipe
import cv2
cap = cv2.VideoCapture("../data/LSA64/video/018_004_005.mp4")

# %%
from utils.video import frame_reader
from utils.mp_utils.render import render_holistic_frame

with mediapipe.solutions.holistic.Holistic(model_complexity=2, static_image_mode=False) as holistic:
    for frame in frame_reader(cap, fps=12):
        res = holistic.process(frame)
        render_holistic_frame(frame, res)

cv2.waitKey(2000)
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1764541441.567921  901257 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1764541441.569210  901944 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.3-arch1.2), renderer: AMD Radeon RX 570 Series (radeonsi, polaris10, ACO, DRM 3.61, 6.12.48-1-MANJARO)
# W0000 00:00:1764541441.609466  901923 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764541441.655168  901925 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1764541441.656893  901939 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
