# %%
from typing import Any

from lightning.pytorch.utilities.types import STEP_OUTPUT, OptimizerLRScheduler
from mpmath.libmp import from_int

from notebooks.inference.simple_rnn import lengths
# %load_ext autoreload
# %autoreload 2

# %%
# Cargar el dataset
from utils.lsa64.dataset import LSA64Dataset
from torch.utils.data import DataLoader, random_split
import torch

dataset = LSA64Dataset("../../data/LSA64/landmarks", hand_label=True)
torch.manual_seed(42)

train_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_size
train_ds, test_ds = random_split(dataset, [train_size, test_size])

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cpu

# %%
from models import SimpleRNN
dominantSignDetector = SimpleRNN(input_dim=114, hidden_dim=114, hidden_layers=5, output_dim=64)
bothSignDetector = SimpleRNN(input_dim=144, hidden_dim=144, hidden_layers=5, output_dim=64)
