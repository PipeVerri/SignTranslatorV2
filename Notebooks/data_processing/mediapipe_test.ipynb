# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Test mediapipe
#
# Voy a usar esto para testear mediapipe. Quiero empezar viendo si realmente no existe una coordenada z reliable para pose estimation

# %%
import mediapipe
import cv2
cap = cv2.VideoCapture("../../data/LSA64/video/018_004_005.mp4")

# %%
from utils.video import frame_reader
from utils.mp_utils.render import render_holistic_frame

with mediapipe.solutions.holistic.Holistic(model_complexity=2, static_image_mode=False) as holistic:
    for frame in frame_reader(cap, fps=12):
        res = holistic.process(frame)
        render_holistic_frame(frame, res)

cv2.waitKey(2000)
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1763831732.292646   11136 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763831732.298197   11225 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.3-arch1.2), renderer: Mesa Intel(R) UHD Graphics 630 (CFL GT2)
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
#
# QObject::moveToThread: Current thread (0x418b9f60) is not the object's thread (0x423cb0e0).
# Cannot move to target thread (0x418b9f60)
